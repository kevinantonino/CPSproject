# %%
import pandas as pd
import numpy as np

# from bokeh.io import output_file
from bokeh.io import output_notebook
from bokeh.plotting import figure, show
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
data = pd.read_csv(r"C:\Users\Caleb\Documents\GitHub\CPSproject\app_development\data\new_Enel_15min_resamp.csv")

# %%
len(data)
# Out:
# 994009

# %%
x= np.full((len(data),1), "Italy")

# %%
data["country"]=x

# %%
x.tolist()
# Out:
# [['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
#  ['Italy'],
# ...

# %%
houseData = data.groupby(data[data['state']=="Brescia"]['time']).mean()

# %%
houseData
# Out:
#                    Unnamed: 0  car1        grid        solar      dataid  \
# time
# 1/1/2020 0:00   654019.222222   0.0  378.837037   -72.970370  546.777778
# 1/1/2020 0:15   654020.222222   0.0  247.162963   -93.777778  546.777778
# 1/1/2020 0:30   654021.222222   0.0  374.266667   -77.755556  546.777778
# 1/1/2020 0:45   654022.222222   0.0  133.792593   -75.940741  546.777778
# 1/1/2020 10:00  663108.250000   0.0 -160.033333   208.416667  547.500000
# ...                       ...   ...         ...          ...         ...
# 9/9/2020 8:45   666102.071429   0.0   92.733333   964.128571  546.428571
# 9/9/2020 9:00   666103.071429   0.0   -9.180952  1163.947619  546.428571
# 9/9/2020 9:15   666104.071429   0.0  -10.432468  1323.809957  546.428571
# 9/9/2020 9:30   666105.071429   0.0   -2.400000  1509.076191  546.428571
# 9/9/2020 9:45   666106.071429   0.0   -5.371429  1673.180952  546.428571
#
#                       load
# time
# 1/1/2020 0:00   513.340741
# ...

# %%
data
# Out:
#         Unnamed: 0                 time  car1       grid      solar  dataid  \
# 0                0        1/1/2020 0:00   0.0  19.600000   0.000000   500.0
# 1                1        1/1/2020 0:15   0.0   7.266667   0.000000   500.0
# 2                2        1/1/2020 0:30   0.0   1.066667   0.000000   500.0
# 3                3        1/1/2020 0:45   0.0   4.933333   0.000000   500.0
# 4                4        1/1/2020 1:00   0.0 -16.733333   0.000000   500.0
# ...            ...                  ...   ...        ...        ...     ...
# 994004      395162  2020-09-30 18:30:00   0.0  23.066667  19.000000   609.0
# 994005      395163  2020-09-30 18:45:00   0.0  16.000000   3.066667   609.0
# 994006      395164  2020-09-30 19:00:00   0.0  22.466667   1.800000   609.0
# 994007      395165  2020-09-30 19:15:00   0.0  18.133333   2.533333   609.0
# 994008      395166  2020-09-30 19:30:00   0.0  45.933333   6.266667   609.0
#
#                load    state country
# ...

# %%
# houseData['time'] = houseData.index
houseData.index[-1]
# houseData
# Out:
# '9/9/2020 9:45'

# %%
houseData[["car1", "grid", "solar", "load"]]
# Out:
#                 car1        grid        solar        load
# time
# 1/1/2020 0:00    0.0  378.837037   -72.970370  513.340741
# 1/1/2020 0:15    0.0  247.162963   -93.777778  512.148148
# 1/1/2020 0:30    0.0  374.266667   -77.755556  506.770370
# 1/1/2020 0:45    0.0  133.792593   -75.940741  401.029630
# 1/1/2020 10:00   0.0 -160.033333   208.416667  225.216667
# ...              ...         ...          ...         ...
# 9/9/2020 8:45    0.0   92.733333   964.128571  614.200000
# 9/9/2020 9:00    0.0   -9.180952  1163.947619  386.219048
# 9/9/2020 9:15    0.0  -10.432468  1323.809957  613.069264
# 9/9/2020 9:30    0.0   -2.400000  1509.076191  571.323810
# 9/9/2020 9:45    0.0   -5.371429  1673.180952  531.038095
#
# [50061 rows x 4 columns]
